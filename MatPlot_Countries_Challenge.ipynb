# %% [markdown]
# # Countries Challenge (using MatPlot, NumPy, & Pandas)

# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
# read countries_clean excel file
c_df = pd.read_excel('Data/countries_clean.xlsx')

# %%
 c_df.head(7)
# Out:
#    Unnamed: 0          Country                               Region  \
# 0           0     Afghanistan         Asia (Ex. Near East)
# 1           1         Albania   Eastern Europe
# 2           2         Algeria   Northern Africa
# 3           3  American Samoa   Oceania
# 4           4         Andorra   Western Europe
# 5           5          Angola   Sub-Saharan Africa
# 6           6        Anguilla               Latin Amer. & Carib
#
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    31056997          647500                        48.0
# 1     3581655           28748                       124.6
# 2    32930091         2381740                        13.8
# 3       57794             199                       290.4
# 4       71201             468                       152.1
# 5    12127071         1246700                         9.7
# 6       13477             102                       132.1
#
#    Coastline (coast/area ratio)  Net migration  \
# ...

# %%
c_df = c_df.drop(columns = ['Unnamed: 0'])

# c_df = c_df.drop(['Unnamed: 0'], axis=1) <--- Alternatively

# %%
c_df.head(7)
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         Asia (Ex. Near East)             31056997
# 1         Albania   Eastern Europe                          3581655
# 2         Algeria   Northern Africa                        32930091
# 3  American Samoa   Oceania                                   57794
# 4         Andorra   Western Europe                            71201
# 5          Angola   Sub-Saharan Africa                     12127071
# 6        Anguilla               Latin Amer. & Carib           13477
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# ...

# %% [markdown]
# ### Check if there are null values

# %%
check_null = c_df.isnull().sum().sum()

print('There are {} null value(s) in this dataframe'.format(check_null))
# Out:
# There are 0 null value(s) in this dataframe
